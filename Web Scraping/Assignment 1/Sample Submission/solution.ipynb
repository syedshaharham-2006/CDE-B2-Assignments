# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
url = 'https://www.thriftbooks.com/browse/?13362col#b.f.t[]=13362&b.col&b.list'

# %%
content = requests.get(url).content
soup = BeautifulSoup(content, 'html.parser')

# %%
script_content = soup.find_all('script')
data = script_content[12].string

# %%
data
# Out:
# '\r\n    window.searchStoreV2 = {\r\n  "displayType": 0,\r\n  "didYouMeanSuggestion": null,\r\n  "originalSearch": null,\r\n  "searchTerm": "",\r\n  "currentPage": 1,\r\n  "totalPages": 426192,\r\n  "totalResults": 21309556,\r\n  "resultsPerPage": 50,\r\n  "isInitialSearch": true,\r\n  "sortDirection": null,\r\n  "sortBy": "mostPopular-desc",\r\n  "isCollectibleFilterEnabled": false,\r\n  "standardFilterGroups": [\r\n    {\r\n      "name": "OutOfStock",\r\n      "description": "",\r\n      "sortOrder": 100,\r\n      "filtersToDisplay": 9999,\r\n      "filterGroupExpanded": true,\r\n      "filters": [\r\n        {\r\n          "id": 1,\r\n          "value": 0,\r\n          "description": "Show Out Of Stock Items",\r\n          "quantityOfResults": 0,\r\n          "enabled": true,\r\n          "sortOrder": 100,\r\n          "filterType": "isOutOfStock"\r\n        }\r\n      ]\r\n    },\r\n    {\r\n      "name": "CollectibleOptions",\r\n      "description": "Collectibles",\r\n      "sortOrder": 450,\r\n      "filtersToDisplay": 3,\r\n      "filterGroupExpanded": true,\r\n      "filters": [\r\n        {\r\n          "id": 2,\r\n          "value": 0,\r\n          "description": "First Editions",\r\n          "quantityOfResults": 0,\r\n          "enabled": false,\r\n          "sortOrder": 0,\r\n          "filterType": "isFirstEdition"\r\n        },\r\n        {\r\n          "id": 1,\r\n          "value": 0,\r\n          "description": "Signed Books",\r\n          "quantityOfResults": 0,\r\n          "enabled": false,\r\n          "sortOrder": 0,\r\n          "filterType": "isSigned"\r\n        },\r\n        {\r\n          "id": -1,\r\n          "value": 0,\r\n          "description": "All Collectibles",\r\n          "quantityOfResults": 0,\r\n          "enabled": false,\r\n          "sortOrder": 0,\r\n          "filterType": "isCollectible"\r\n        }\r\n      ]\r\n    },\r\n    {\r\n      "name": "AdditionalOptions",\r\n      "description": "Additional Options",\r\n      "sortOrder": 700,\r\n      "filtersToDisplay": 9999,\r\n      "filterGroupExpanded": true,\r\n      "filters": [\r\n        {\r\n          "id": 100,\r\n          "value": 0,\r\n          "description": "New Releases",\r\n          "quantityOfResults": 0,\r\n          "enabled": false,\r\n          "sortOrder": 100,\r\n          "filterType": "isNewRelease"\r\n        },\r\n        {\r\n          "id": 200,\r\n          "value": 0,\r\n          "description": "ThriftBooks Deals",\r\n          "quantityOfResults": 0,\r\n          "enabled": false,\r\n          "sortOrder": 200,\r\n          "filterType": "isBargainItem"\r\n        }\r\n      ]\r\n    },\r\n    {\r\n      "name": "Languages",\r\n      "description": "Languages",\r\n      "sortOrder": 600,\r\n      "filtersToDisplay": 3,\r\n      "filterGroupExpanded": false,\r\n      "filters": [\r\n        {\r\n          "id": 40,\r\n          "value": 40,\r\n          "description": "English",\r\n          "quantityOfResults": 0,\r\n          "enabled": false,\r\n          "sortOrder": 0,\r\n          "filterType": "languages"\r\n        },\r\n        {\r\n          "id": 54,\r\n          "value": 54,\r\n          "description": "German",\r\n          "quantityOfResults": 0,\r\n          "enabled": false,\r\n          "sortOrder": 1,\r\n          "filterType": "languages"\r\n        },\r\n        {\r\n          "id": 48,\r\n          "value": 48,\r\n          "description": "French",\r\n          "quantityOfResults": 0,\r\n          "enabled": false,\r\n          "sortOrder": 2,\r\n          "filterType": "languages"\r\n        },\r\n        {\r\n          "id": 123,\r\n          "value": 123,\r\n          "description": "Spanish",\r\n          "quantityOfResults": 0,\r\n          "enabled": false,\r\n          "sortOrder": 3,\r\n          "filterType": "languages"\r\n        },\r\n        {\r\n          "id": 69,\r\n          "value": 69,\r\n          "description": "Italian",\r\n          "quantityOfResults": 0 ...
